# %% [markdown]
# ![image.png](https://i.imgur.com/a3uAqnb.png)
#
# # Text Classification with Neural Networks - Homework Assignment
#
# In this homework, you will implement multiple **neural network architectures for text classification** to detect sarcasm in news headlines. This project will help you understand the fundamentals of text preprocessing, feature extraction, and various neural network approaches for NLP tasks.
#
# ## 📌 Project Overview
# - **Task**: Classify news headlines as sarcastic or non-sarcastic
# - **Architectures**: Naive Bayes, 2-Layer NN, RNN, GRU, and LSTM
# - **Dataset**: News Headlines Dataset for Sarcasm Detection
# - **Goal**: Compare different approaches for text classification
#
# ## 📚 Learning Objectives
# By completing this assignment, you will:
# - Understand text preprocessing and feature extraction techniques
# - Learn TF-IDF vectorization for text data
# - Implement multiple neural network architectures for text classification
# - Compare traditional ML with deep learning approaches
# - Practice evaluation metrics for classification tasks

# %% [markdown]
# ## 1️⃣ Initial Setup and Data Download
#
# **Task**: Download the sarcasm detection dataset and explore its structure.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rmisra/news-headlines-dataset-for-sarcasm-detection")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/ali/.cache/kagglehub/datasets/rmisra/news-headlines-dataset-for-sarcasm-detection/versions/2

# %%
import os
os.listdir(path)
# Out:
# ['Sarcasm_Headlines_Dataset.json', 'Sarcasm_Headlines_Dataset_v2.json']

# %% [markdown]
# ## 2️⃣ Data Loading and Exploration
#
# **Task**: Load the dataset and perform initial exploration to understand the data structure and characteristics.
#
# **Requirements**:
# - Load the JSON dataset
# - Convert to DataFrame format
# - Explore class distribution
# - Display sample headlines from both classes
# - Analyze basic statistics about headline lengths

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# TODO: Load the dataset from JSON file
# TODO: Convert to DataFrame
# TODO: Calculate and display class proportions

# %%
# TODO: Display examples of sarcastic headlines
# TODO: Display examples of non-sarcastic headlines
# Out:
# ==================================================
# EXAMPLES OF SARCASTIC HEADLINES:
# ==================================================
# 1. thirtysomething scientists unveil doomsday clock of hair loss
# 2. inclement weather prevents liar from getting to work
# 3. mother comes pretty close to using word 'streaming' correctly
# 4. richard branson's global-warming donation nearly as much as cost of failed balloon trips
# 5. shadow government getting too large to meet in marriott conference room b
#
# ==================================================
# EXAMPLES OF NON-SARCASTIC HEADLINES:
# ==================================================
# 1. dem rep. totally nails why congress is falling short on gender, racial equality
# 2. eat your veggies: 9 deliciously different recipes
# 3. my white inheritance
# 4. 5 ways to file your taxes with less stress
# 5. lots of parents know this scenario

# %%
# TODO: Calculate basic statistics about headline lengths
# TODO: Create visualizations for class distribution and word count analysis

# %% [markdown]
# ## 3️⃣ Text Preprocessing and Feature Engineering
#
# **Task**: Implement comprehensive text preprocessing pipeline for neural network training.
#
# **Requirements**:
# - Download required NLTK data
# - Implement text cleaning and preprocessing function
# - Apply preprocessing to all headlines
# - Create train-test split with stratification

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import string
#uncomment if needed
#nltk.download('punkt', quiet=True)
#nltk.download('stopwords', quiet=True)
#nltk.download('punkt_tab',quiet=True)
# Out:
# True

# %%
# TODO: Initialize preprocessing tools (stemmer, stopwords)
# TODO: Implement comprehensive text preprocessing function
# TODO: Apply preprocessing to headlines
# TODO: Create feature and label variables
# TODO: Perform train-test split with stratification
# Out:
# Preprocessing headlines...
# Dataset after preprocessing: 28617 samples
# Train set: 22893 samples | Test set: 5724 samples
# Train class distribution: {0: 11986, 1: 10907}

# %%
# TODO: Show preprocessing examples comparing original vs processed text
# Out:
# Preprocessing Examples:
# Original: thirtysomething scientists unveil doomsday clock of hair loss
# Processed: thirtysometh scientist unveil doomsday clock hair loss
# Label: 1
#
# Original: dem rep. totally nails why congress is falling short on gender, racial equality
# Processed: dem rep total nail congress fall short gender racial equal
# Label: 0
#
# Original: eat your veggies: 9 deliciously different recipes
# Processed: eat veggi delici differ recip
# Label: 0

# %% [markdown]
# ## 4️⃣ TF-IDF Vectorization and Naive Bayes Baseline
#
# **Task**: Create TF-IDF feature matrices and implement a Naive Bayes baseline model.
#
# **Requirements**:
# - Create TF-IDF vectorizer with appropriate parameters
# - Transform text data into numerical features
# - Train and evaluate Naive Bayes classifier
# - Store results for final comparison

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# TODO: Create TF-IDF vectorizer with max_features, min_df, max_df, ngram_range parameters
# TODO: Fit vectorizer on training data and transform both train and test sets
# TODO: Display TF-IDF matrix shapes



# TODO: Train Naive Bayes model
# TODO: Make predictions on train and test sets
# TODO: Calculate accuracies
# TODO: Store results in results dictionary
# TODO: Display classification report
# Out:
# Creating TF-IDF matrices...
# TF-IDF matrix shape - Train: (22893, 10000), Test: (5724, 10000)
#
# Training Naive Bayes model...
# Naive Bayes - Train Accuracy: 0.8670
# Naive Bayes - Test Accuracy: 0.7956
#
# Naive Bayes Classification Report:
#                precision    recall  f1-score   support
#
# Non-Sarcastic       0.79      0.83      0.81      2997
#     Sarcastic       0.80      0.76      0.78      2727
#
#      accuracy                           0.80      5724
#     macro avg       0.80      0.79      0.79      5724
#  weighted avg       0.80      0.80      0.80      5724

# %% [markdown]
# ## 5️⃣ 2-Layer Neural Network on TF-IDF Features
#
# **Task**: Implement a 2-layer neural network using TF-IDF features as input.
#
# **Requirements**:
# - Convert TF-IDF matrices to PyTorch tensors
# - Define 2-layer neural network architecture
# - Implement training loop with proper batch processing
# - Evaluate model performance

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import accuracy_score
import numpy as np

# TODO: Convert TF-IDF matrices to PyTorch tensors
# TODO: Create DataLoaders for batch processing


# TODO: Define 2-layer neural network class
class TwoLayerNN(nn.Module):
    def __init__(self, input_size, hidden_size=128, num_classes=2):
        super(TwoLayerNN, self).__init__()
        # TODO: Define layers (fc1, relu, dropout, fc2)
        
    def forward(self, x):
        # TODO: Implement forward pass
        pass

# TODO: Initialize model, criterion, and optimizer
# TODO: Set device (CPU/GPU)



# TODO: Implement training loop for specified epochs
# TODO: Include both training and validation phases
# TODO: Track and display training progress
# TODO: Save best model based on validation loss


# TODO: Evaluate model on train and test sets
# TODO: Calculate accuracies and store results
# TODO: Display classification report
# Out:
# Training on device: cuda
# Model architecture: 10000 -> 128 -> 2
# Epoch [5/20], Loss: 0.1802
# Epoch [10/20], Loss: 0.0442
# Epoch [15/20], Loss: 0.0108
# Epoch [20/20], Loss: 0.0046
#
# 2-Layer NN - Train Accuracy: 0.9994
# 2-Layer NN - Test Accuracy: 0.7696
#
# 2-Layer NN Classification Report:
#                precision    recall  f1-score   support
#
# Non-Sarcastic       0.77      0.80      0.78      2997
#     Sarcastic       0.77      0.74      0.75      2727
#
#      accuracy                           0.77      5724
#     macro avg       0.77      0.77      0.77      5724
#  weighted avg       0.77      0.77      0.77      5724

# %% [markdown]
# ## 6️⃣ Text Tokenization for RNN Models
#
# **Task**: Prepare text data for RNN-based models by building vocabulary and converting text to sequences.
#
# **Requirements**:
# - Build vocabulary from training data with frequency threshold
# - Convert text to sequences of vocabulary indices
# - Pad sequences to uniform length
# - Create DataLoaders for RNN training

# %%
from collections import Counter
from torch.nn.utils.rnn import pad_sequence

# TODO: Implement vocabulary building function with minimum frequency threshold
# TODO: Build vocabulary from training data
# TODO: Display vocabulary size


# TODO: Implement text to sequence conversion function
# TODO: Tokenize all training and test data
# TODO: Convert to tensors and pad sequences to uniform length
# TODO: Create DataLoaders for RNN models
# Out:
# Vocabulary size: 9678
# Tokenized sequences shape - Train: torch.Size([22893, 50]), Test: torch.Size([5724, 50])

# %%
# TODO: Display tokenization examples showing original text, token indices, and corresponding words
# Out:
# Tokenization Examples:
# Original: white hous block seahawk punt
# Tokens: [2, 3, 4, 5, 1]
# Words: ['white', 'hous', 'block', 'seahawk', '<UNK>']
#
# Original: nation sport fan shock truth rock anthem
# Tokens: [6, 7, 8, 9, 10, 11, 12]
# Words: ['nation', 'sport', 'fan', 'shock', 'truth', 'rock', 'anthem']
#
# Original: drunken episod repeat
# Tokens: [13, 14, 15]
# Words: ['drunken', 'episod', 'repeat']
#
# Ready for RNN training! Vocab size: 9678, Max sequence length: 50

# %% [markdown]
# ## 7️⃣ Recurrent Neural Network (RNN) Implementation
#
# **Task**: Implement a Recurrent Neural Network for text classification using word embeddings.
#
# **Requirements**:
# - Define RNN architecture with embedding layer
# - Implement proper masking for padded sequences
# - Use average pooling over sequence length
# - Train and evaluate the RNN model

# %%
import torch.nn as nn

# TODO: Define RNN classifier class
class RNNClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim=128, hidden_dim=256, num_classes=2, num_layers=2):
        super(RNNClassifier, self).__init__()
        # TODO: Define embedding layer with padding_idx
        # TODO: Define RNN layer with dropout
        # TODO: Define dropout and fully connected layers
        
    def forward(self, x):
        # TODO: Create mask for padding tokens
        # TODO: Apply embedding layer
        # TODO: Pass through RNN
        # TODO: Apply masking and average pooling
        # TODO: Apply dropout and final classification layer
        pass

# TODO: Initialize RNN model, criterion, and optimizer
# Out:
# RNN Model Architecture:
# Embedding: 9678 -> 128
# RNN: 128 -> 256 (2 layers)
# Output: 256 -> 2
#
# Training RNN model...
# Epoch [5/20], Loss: 0.3664, Train Acc: 83.89%
# Epoch [10/20], Loss: 0.2740, Train Acc: 88.59%
# Epoch [15/20], Loss: 0.2309, Train Acc: 90.35%
# Epoch [20/20], Loss: 0.1973, Train Acc: 92.00%
#
# RNN - Train Accuracy: 0.9424
# RNN - Test Accuracy: 0.7715
#
# RNN Classification Report:
#                precision    recall  f1-score   support
#
# Non-Sarcastic       0.77      0.81      0.79      2997
#     Sarcastic       0.78      0.73      0.75      2727
#
#      accuracy                           0.77      5724
#     macro avg       0.77      0.77      0.77      5724
#  weighted avg       0.77      0.77      0.77      5724

# %%
# TODO: Implement training function for RNN models
def train_rnn_model(model, train_loader, criterion, optimizer, num_epochs=20):
    # TODO: Training loop with gradient clipping
    # TODO: Display training progress every 5 epochs
    pass

# TODO: Train RNN model

# %%
# TODO: Implement evaluation function for RNN models
def evaluate_rnn_model(model, train_loader, test_loader, device):
    # TODO: Set model to evaluation mode
    # TODO: Get predictions for both train and test sets
    # TODO: Return predictions and labels
    pass

# TODO: Evaluate RNN model and calculate accuracies
# TODO: Store results and display classification report

# %% [markdown]
# ## 8️⃣ Gated Recurrent Unit (GRU) Implementation
#
# **Task**: Implement a bidirectional GRU model for improved sequence modeling.
#
# **Requirements**:
# - Define GRU architecture with bidirectional processing
# - Handle doubled hidden dimension from bidirectional GRU
# - Apply same training and evaluation procedures
# - Compare performance with basic RNN

# %%
import torch.nn as nn

# TODO: Define GRU classifier class
class GRUClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim=128, hidden_dim=256, num_classes=2, num_layers=2):
        super(GRUClassifier, self).__init__()
        # TODO: Define embedding layer
        # TODO: Define bidirectional GRU layer
        # TODO: Define dropout and fully connected layers (note: bidirectional doubles hidden_dim)
        
    def forward(self, x):
        # TODO: Implement forward pass similar to RNN but with GRU
        # TODO: Handle bidirectional output dimensions
        pass

# TODO: Initialize GRU model, criterion, and optimizer
# Out:
# GRU Model Architecture:
# Embedding: 9678 -> 128
# Bidirectional GRU: 128 -> 256*2 (2 layers)
# Output: 512 -> 2
#
# Training GRU model...
# Epoch [5/20], Loss: 0.2668, Train Acc: 89.00%
# Epoch [10/20], Loss: 0.1135, Train Acc: 95.54%
# Epoch [15/20], Loss: 0.0652, Train Acc: 97.58%
# Epoch [20/20], Loss: 0.0540, Train Acc: 98.08%
#
# GRU - Train Accuracy: 0.9917
# GRU - Test Accuracy: 0.7739
#
# GRU Classification Report:
#                precision    recall  f1-score   support
#
# Non-Sarcastic       0.79      0.77      0.78      2997
#     Sarcastic       0.76      0.77      0.77      2727
#
#      accuracy                           0.77      5724
#     macro avg       0.77      0.77      0.77      5724
#  weighted avg       0.77      0.77      0.77      5724

# %%
# TODO: Train GRU model using the same training function

# %%
# TODO: Evaluate GRU model and calculate accuracies
# TODO: Store results and display classification report

# %% [markdown]
# ## 9️⃣ Long Short-Term Memory (LSTM) Implementation
#
# **Task**: Implement a bidirectional LSTM model for capturing long-term dependencies in text.
#
# **Requirements**:
# - Define LSTM architecture with bidirectional processing
# - Handle both hidden and cell states from LSTM
# - Apply consistent training methodology
# - Compare with RNN and GRU performance

# %%
import torch.nn as nn

# TODO: Define LSTM classifier class
class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim=128, hidden_dim=256, num_classes=2, num_layers=2):
        super(LSTMClassifier, self).__init__()
        # TODO: Define embedding layer
        # TODO: Define bidirectional LSTM layer
        # TODO: Define dropout and fully connected layers
        
    def forward(self, x):
        # TODO: Implement forward pass with LSTM
        # TODO: Handle LSTM output (includes both hidden and cell states)
        pass

# TODO: Initialize LSTM model, criterion, and optimizer
# Out:
# LSTM Model Architecture:
# Embedding: 9678 -> 128
# Bidirectional LSTM: 128 -> 256*2 (2 layers)
# Output: 512 -> 2
#
# Training LSTM model...
# Epoch [5/20], Loss: 0.2781, Train Acc: 88.21%
# Epoch [10/20], Loss: 0.1286, Train Acc: 95.02%
# Epoch [15/20], Loss: 0.0733, Train Acc: 97.27%
# Epoch [20/20], Loss: 0.0578, Train Acc: 98.00%
#
# LSTM - Train Accuracy: 0.9897
# LSTM - Test Accuracy: 0.7757
#
# LSTM Classification Report:
#                precision    recall  f1-score   support
#
# Non-Sarcastic       0.77      0.81      0.79      2997
#     Sarcastic       0.78      0.74      0.76      2727
#
#      accuracy                           0.78      5724
#     macro avg       0.78      0.77      0.77      5724
#  weighted avg       0.78      0.78      0.78      5724

# %%
# TODO: Train LSTM model (using same function)

# %%
# TODO: Evaluate LSTM model and calculate accuracies
# TODO: Store results and display classification report

# %% [markdown]
# ## 🔟 Comprehensive Model Comparison and Analysis
#
# **Task**: Compare all implemented models and analyze their performance through visualizations and metrics.
#
# **Requirements**:
# - Create comprehensive results summary comparing all models
# - Generate confusion matrices for each model
# - Visualize training progress and model rankings
# - Analyze overfitting and generalization performance
# - Provide detailed performance breakdown

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import pandas as pd

# TODO: Create comprehensive results summary
# TODO: Create results DataFrame with train/test accuracies and overfitting metrics
# TODO: Find and display best performing model


# TODO: Create comprehensive visualization with subplots
# TODO: Plot 1: Train vs Test Accuracy comparison
# TODO: Plot 2: Overfitting analysis (Train - Test accuracy difference)
# TODO: Plot 3: Model ranking by test accuracy
# TODO: Generate confusion matrices for all models in remaining subplots
# Out:
# ================================================================================
# FINAL MODEL COMPARISON - SARCASM DETECTION
# ================================================================================
#          Model  Train Accuracy  Test Accuracy  Overfitting (Train-Test)
# 0  Naive Bayes          0.8670         0.7956                    0.0714
# 1   2-Layer NN          0.9994         0.7696                    0.2298
# 2          RNN          0.9424         0.7715                    0.1709
# 3          GRU          0.9917         0.7739                    0.2178
# 4         LSTM          0.9897         0.7757                    0.2141
#
# Best performing model: Naive Bayes with 0.7956 test accuracy

# %%
# TODO: Provide detailed analysis for each model
# TODO: Calculate precision and recall for both classes from confusion matrices
# TODO: Display detailed metrics breakdown for each model
# Out:
# Naive Bayes:
#   Non-Sarcastic - Precision: 0.7918, Recall: 0.8272
#   Sarcastic - Precision: 0.8002, Recall: 0.7609
#
# 2-Layer NN:
#   Non-Sarcastic - Precision: 0.7715, Recall: 0.7955
#   Sarcastic - Precision: 0.7673, Recall: 0.7411
#
# RNN:
#   Non-Sarcastic - Precision: 0.7680, Recall: 0.8075
#   Sarcastic - Precision: 0.7757, Recall: 0.7319
#
# GRU:
#   Non-Sarcastic - Precision: 0.7897, Recall: 0.7744
#   Sarcastic - Precision: 0.7573, Recall: 0.7734
#
# LSTM:
#   Non-Sarcastic - Precision: 0.7713, Recall: 0.8125
#   Sarcastic - Precision: 0.7811, Recall: 0.7352

# %% [markdown]
# ## 📝 Evaluation Criteria
#
# Your homework will be evaluated based on:
#
# 1. **Implementation Correctness (40%)**
#    - Proper text preprocessing pipeline
#    - Correct TF-IDF vectorization
#    - Working neural network architectures (2-Layer NN, RNN, GRU, LSTM)
#    - Appropriate tokenization and vocabulary building for RNN models
#
# 2. **Model Performance (30%)**
#    - Reasonable classification accuracy across all models
#    - Proper convergence during training
#    - Meaningful comparison between different approaches
#    - Appropriate handling of text data and sequence modeling
#
# 3. **Code Quality and Analysis (30%)**
#    - Clean, readable code with proper structure
#    - Comprehensive model comparison and visualization
#    - Insightful analysis of results and model differences
#    - Good coding practices and efficient implementation

# %% [markdown]
# # Dataset Source
# 1. Misra, Rishabh and Prahal Arora. "Sarcasm Detection using News Headlines Dataset." AI Open (2023).
# 2. Misra, Rishabh and Jigyasa Grover. "Sculpting Data for ML: The first act of Machine Learning." ISBN 9798585463570 (2021).
