# %% [markdown]
# ## Task: Predict Carbon Emissions Based on Satellite Observations
#
# * You are provided with a time series satellite observations dataset extracted from Sentinel-5P satelite from 2019 to 2021.
#
# * Your objective is to build a regression model that accurately predicts the amount of carbon emissions in the next years.
#
# * Your target is the column: "emission".
#
# * You are provided with the code to download and load the csv file.
#
# * Your work will be evaluated based on the completion of the given tasks below.
#
# * You are allowed to use any models or libraries you want.
#
# ---

# %%
import pandas as pd
import gdown
import kagglehub
import os

# %%
path = kagglehub.dataset_download("mohammad2012191/q3-data")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'q3-data' dataset.
# Path to dataset files: /kaggle/input/q3-data

# %%
csv_path = os.path.join(path, "train.csv")

data = pd.read_csv(csv_path)
data.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00     -0.51      29.29  2019        0
# 1  ID_-0.510_29.290_2019_01     -0.51      29.29  2019        1
# 2  ID_-0.510_29.290_2019_02     -0.51      29.29  2019        2
# 3  ID_-0.510_29.290_2019_03     -0.51      29.29  2019        3
# 4  ID_-0.510_29.290_2019_04     -0.51      29.29  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                 -0.000108
# 1                                  0.000021
# 2                                  0.000514
# 3                                       NaN
# 4                                 -0.000079
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.603019
# 1                                      0.728214
# 2                                      0.748199
# 3                                           NaN
# 4                                      0.676296
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                       -0.000065
# 1                                        0.000014
# 2                                        0.000385
# 3                                             NaN
# 4                                       -0.000048
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                       0.255668                           -98.593887  ...
# 1                       0.130988                            16.592861  ...
# 2                       0.110018                            72.795837  ...
# 3                            NaN                                  NaN  ...
# 4                       0.121164                             4.121269  ...
#
#    Cloud_cloud_top_height  Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0             3664.436218               61085.809570              2615.120483
# 1             3651.190311               66969.478735              3174.572424
# 2             4216.986492               60068.894448              3516.282669
# 3             5228.507736               51064.547339              4180.973322
# 4             3980.598120               63751.125781              3355.710107
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                  15.568533              0.272292
# 1                   8.690601              0.256830
# 2                  21.103410              0.251101
# 3                  15.386899              0.262043
# 4                   8.114694              0.235847
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                  -12.628986                  35.632416
# 1                   30.359375                  39.557633
# 2                   15.377883                  30.401823
# 3                  -11.293399                  24.380357
# 4                   38.532263                  37.392979
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle  emission
# 0                -138.786423                 30.752140  3.750994
# 1                -145.183930                 27.251779  4.025176
# 2                -142.519545                 26.193296  4.231381
# 3                -132.665828                 28.829155  4.305286
# 4                -141.509805                 22.204612  4.347317
#
# [5 rows x 76 columns]

# %% [markdown]
# # EDA & Preprocessing

# %% [markdown]
# 1. Drop the ID feature (ID_LAT_LON_YEAR_WEEK):

# %%
# 1. TODO
data = data.drop('ID_LAT_LON_YEAR_WEEK',axis=1)

# %%
data
# Out:
#        latitude  longitude  year  week_no  \
# 0        -0.510     29.290  2019        0
# 1        -0.510     29.290  2019        1
# 2        -0.510     29.290  2019        2
# 3        -0.510     29.290  2019        3
# 4        -0.510     29.290  2019        4
# ...         ...        ...   ...      ...
# 79018    -3.299     30.301  2021       48
# 79019    -3.299     30.301  2021       49
# 79020    -3.299     30.301  2021       50
# 79021    -3.299     30.301  2021       51
# 79022    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# 2                                      0.000514
# 3                                           NaN
# 4                                     -0.000079
# ...                                         ...
# 79018                                  0.000284
# 79019                                  0.000083
# 79020                                       NaN
# 79021                                 -0.000034
# 79022                                 -0.000091
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# 0                                          0.603019
# 1                                          0.728214
# 2                                          0.748199
# 3                                               NaN
# 4                                          0.676296
# ...                                             ...
# 79018                                      1.195643
# 79019                                      1.130868
# 79020                                           NaN
# 79021                                      0.879397
# 79022                                      0.871951
#
#        SulphurDioxide_SO2_slant_column_number_density  \
# 0                                           -0.000065
# 1                                            0.000014
# 2                                            0.000385
# 3                                                 NaN
# 4                                           -0.000048
# ...                                               ...
# 79018                                        0.000340
# 79019                                        0.000063
# 79020                                             NaN
# 79021                                       -0.000028
# 79022                                       -0.000079
#
#        SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# 0                           0.255668                           -98.593887
# 1                           0.130988                            16.592861
# 2                           0.110018                            72.795837
# 3                                NaN                                  NaN
# 4                           0.121164                             4.121269
# ...                              ...                                  ...
# 79018                       0.191313                            72.820518
# 79019                       0.177222                           -12.856753
# 79020                            NaN                                  NaN
# 79021                       0.184209                          -100.344827
# 79022                       0.000000                            76.825638
#
#        SulphurDioxide_sensor_zenith_angle  ...  Cloud_cloud_top_height  \
# 0                               50.843559  ...             3664.436218
# 1                               39.137194  ...             3651.190311
# 2                               52.868816  ...             4216.986492
# 3                                     NaN  ...             5228.507736
# 4                               35.515587  ...             3980.598120
# ...                                   ...  ...                     ...
# 79018                           55.988022  ...             5459.185355
# 79019                           19.435339  ...             5606.449457
# 79020                                 NaN  ...             6222.646776
# 79021                           32.599393  ...             7896.456885
# 79022                            8.273742  ...             7553.295016
#
#        Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0                   61085.809570              2615.120483
# 1                   66969.478735              3174.572424
# 2                   60068.894448              3516.282669
# 3                   51064.547339              4180.973322
# 4                   63751.125781              3355.710107
# ...                          ...                      ...
# 79018               60657.101913              4590.879504
# 79019               60168.191528              4659.130378
# 79020               56596.027209              5222.646823
# 79021               46533.348194              6946.858022
# 79022               47771.681887              6553.295018
#
#        Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                      15.568533              0.272292
# 1                       8.690601              0.256830
# 2                      21.103410              0.251101
# 3                      15.386899              0.262043
# 4                       8.114694              0.235847
# ...                          ...                   ...
# 79018                  20.245954              0.304797
# 79019                   6.104610              0.314015
# 79020                  14.817885              0.288058
# 79021                  32.594768              0.274047
# 79022                  19.464032              0.226276
#
#        Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                      -12.628986                  35.632416
# 1                       30.359375                  39.557633
# 2                       15.377883                  30.401823
# 3                      -11.293399                  24.380357
# 4                       38.532263                  37.392979
# ...                           ...                        ...
# 79018                  -35.140368                  40.113533
# 79019                    4.667058                  47.528435
# 79020                   -0.340922                  35.328098
# 79021                    8.427699                  48.295652
# 79022                  -12.808528                  47.923441
#
#        Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle   emission
# 0                    -138.786423                 30.752140   3.750994
# 1                    -145.183930                 27.251779   4.025176
# 2                    -142.519545                 26.193296   4.231381
# 3                    -132.665828                 28.829155   4.305286
# 4                    -141.509805                 22.204612   4.347317
# ...                          ...                       ...        ...
# 79018                -129.935508                 32.095214  29.404171
# 79019                -134.252871                 30.771469  29.186497
# 79020                -134.731723                 30.716166  29.131205
# 79021                -139.447849                 29.112868  28.125792
# 79022                -136.299984                 30.246387  27.239302
#
# [79023 rows x 75 columns]

# %% [markdown]
# 2. Check for the missing values and handle them.

# %%
# 2. TODO
# data.isna().sum()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 75 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   latitude                                                  79023 non-null  float64
#  1   longitude                                                 79023 non-null  float64
#  2   year                                                      79023 non-null  int64
#  3   week_no                                                   79023 non-null  int64
#  4   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  5   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  6   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
#  7   SulphurDioxide_cloud_fraction                             64414 non-null  float64
#  8   SulphurDioxide_sensor_azimuth_angle                       64414 non-null  float64
#  9   SulphurDioxide_sensor_zenith_angle                        64414 non-null  float64
#  10  SulphurDioxide_solar_azimuth_angle                        64414 non-null  float64
#  11  SulphurDioxide_solar_zenith_angle                         64414 non-null  float64
#  12  SulphurDioxide_SO2_column_number_density_15km             64414 non-null  float64
#  13  CarbonMonoxide_CO_column_number_density                   76901 non-null  float64
#  14  CarbonMonoxide_H2O_column_number_density                  76901 non-null  float64
#  15  CarbonMonoxide_cloud_height                               76901 non-null  float64
#  16  CarbonMonoxide_sensor_altitude                            76901 non-null  float64
#  17  CarbonMonoxide_sensor_azimuth_angle                       76901 non-null  float64
#  18  CarbonMonoxide_sensor_zenith_angle                        76901 non-null  float64
#  19  CarbonMonoxide_solar_azimuth_angle                        76901 non-null  float64
#  20  CarbonMonoxide_solar_zenith_angle                         76901 non-null  float64
#  21  NitrogenDioxide_NO2_column_number_density                 60703 non-null  float64
#  22  NitrogenDioxide_tropospheric_NO2_column_number_density    60703 non-null  float64
#  23  NitrogenDioxide_stratospheric_NO2_column_number_density   60703 non-null  float64
#  24  NitrogenDioxide_NO2_slant_column_number_density           60703 non-null  float64
#  25  NitrogenDioxide_tropopause_pressure                       60703 non-null  float64
#  26  NitrogenDioxide_absorbing_aerosol_index                   60703 non-null  float64
#  27  NitrogenDioxide_cloud_fraction                            60703 non-null  float64
#  28  NitrogenDioxide_sensor_altitude                           60703 non-null  float64
#  29  NitrogenDioxide_sensor_azimuth_angle                      60703 non-null  float64
#  30  NitrogenDioxide_sensor_zenith_angle                       60703 non-null  float64
#  31  NitrogenDioxide_solar_azimuth_angle                       60703 non-null  float64
#  32  NitrogenDioxide_solar_zenith_angle                        60703 non-null  float64
#  33  Formaldehyde_tropospheric_HCHO_column_number_density      71746 non-null  float64
#  34  Formaldehyde_tropospheric_HCHO_column_number_density_amf  71746 non-null  float64
#  35  Formaldehyde_HCHO_slant_column_number_density             71746 non-null  float64
#  36  Formaldehyde_cloud_fraction                               71746 non-null  float64
#  37  Formaldehyde_solar_zenith_angle                           71746 non-null  float64
#  38  Formaldehyde_solar_azimuth_angle                          71746 non-null  float64
#  39  Formaldehyde_sensor_zenith_angle                          71746 non-null  float64
#  40  Formaldehyde_sensor_azimuth_angle                         71746 non-null  float64
#  41  UvAerosolIndex_absorbing_aerosol_index                    78484 non-null  float64
#  42  UvAerosolIndex_sensor_altitude                            78484 non-null  float64
#  43  UvAerosolIndex_sensor_azimuth_angle                       78484 non-null  float64
#  44  UvAerosolIndex_sensor_zenith_angle                        78484 non-null  float64
#  45  UvAerosolIndex_solar_azimuth_angle                        78484 non-null  float64
#  46  UvAerosolIndex_solar_zenith_angle                         78484 non-null  float64
#  47  Ozone_O3_column_number_density                            78475 non-null  float64
#  48  Ozone_O3_column_number_density_amf                        78475 non-null  float64
#  49  Ozone_O3_slant_column_number_density                      78475 non-null  float64
#  50  Ozone_O3_effective_temperature                            78475 non-null  float64
#  51  Ozone_cloud_fraction                                      78475 non-null  float64
#  52  Ozone_sensor_azimuth_angle                                78475 non-null  float64
#  53  Ozone_sensor_zenith_angle                                 78475 non-null  float64
#  54  Ozone_solar_azimuth_angle                                 78475 non-null  float64
#  55  Ozone_solar_zenith_angle                                  78475 non-null  float64
#  56  UvAerosolLayerHeight_aerosol_height                       439 non-null    float64
#  57  UvAerosolLayerHeight_aerosol_pressure                     439 non-null    float64
#  58  UvAerosolLayerHeight_aerosol_optical_depth                439 non-null    float64
#  59  UvAerosolLayerHeight_sensor_zenith_angle                  439 non-null    float64
#  60  UvAerosolLayerHeight_sensor_azimuth_angle                 439 non-null    float64
#  61  UvAerosolLayerHeight_solar_azimuth_angle                  439 non-null    float64
#  62  UvAerosolLayerHeight_solar_zenith_angle                   439 non-null    float64
#  63  Cloud_cloud_fraction                                      78539 non-null  float64
#  64  Cloud_cloud_top_pressure                                  78539 non-null  float64
#  65  Cloud_cloud_top_height                                    78539 non-null  float64
#  66  Cloud_cloud_base_pressure                                 78539 non-null  float64
#  67  Cloud_cloud_base_height                                   78539 non-null  float64
#  68  Cloud_cloud_optical_depth                                 78539 non-null  float64
#  69  Cloud_surface_albedo                                      78539 non-null  float64
#  70  Cloud_sensor_azimuth_angle                                78539 non-null  float64
#  71  Cloud_sensor_zenith_angle                                 78539 non-null  float64
#  72  Cloud_solar_azimuth_angle                                 78539 non-null  float64
#  73  Cloud_solar_zenith_angle                                  78539 non-null  float64
#  74  emission                                                  79023 non-null  float64
# dtypes: float64(73), int64(2)
# memory usage: 45.2 MB

# %%
data = data.fillna(data.mean())

# %% [markdown]
# 3. Plot the "emission" histogram.

# %%
# 3. TODO
data.emission.hist(bins=30)
# Out:
# <Axes: >

# %% [markdown]
# 4. Plot the "latitude" and "longitude" using a scatter plot then colorize the points using the "emission" column.

# %%
# 4. TODO
import matplotlib.pyplot as plt
plt.scatter(data["latitude"],data["longitude"],c=data["emission"])

# %% [markdown]
# # Feature engineering

# %% [markdown]
# 1. Add a new feature representing "Location" (To do that, you should convert "longitude" and "latitude" features to string type, concatenate them and add the result as a new feature).

# %%
# 1. TODO
data["location"] = data["longitude"].astype(str) + data["latitude"].astype(str)

# %%
data
# Out:
#        latitude  longitude  year  week_no  \
# 0        -0.510     29.290  2019        0
# 1        -0.510     29.290  2019        1
# 2        -0.510     29.290  2019        2
# 3        -0.510     29.290  2019        3
# 4        -0.510     29.290  2019        4
# ...         ...        ...   ...      ...
# 79018    -3.299     30.301  2021       48
# 79019    -3.299     30.301  2021       49
# 79020    -3.299     30.301  2021       50
# 79021    -3.299     30.301  2021       51
# 79022    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# 2                                      0.000514
# 3                                      0.000048
# 4                                     -0.000079
# ...                                         ...
# 79018                                  0.000284
# 79019                                  0.000083
# 79020                                  0.000048
# 79021                                 -0.000034
# 79022                                 -0.000091
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# 0                                          0.603019
# 1                                          0.728214
# 2                                          0.748199
# 3                                          0.834848
# 4                                          0.676296
# ...                                             ...
# 79018                                      1.195643
# 79019                                      1.130868
# 79020                                      0.834848
# 79021                                      0.879397
# 79022                                      0.871951
#
#        SulphurDioxide_SO2_slant_column_number_density  \
# 0                                           -0.000065
# 1                                            0.000014
# 2                                            0.000385
# 3                                            0.000035
# 4                                           -0.000048
# ...                                               ...
# 79018                                        0.000340
# 79019                                        0.000063
# 79020                                        0.000035
# 79021                                       -0.000028
# 79022                                       -0.000079
#
#        SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# 0                           0.255668                           -98.593887
# 1                           0.130988                            16.592861
# 2                           0.110018                            72.795837
# 3                           0.158418                            -7.925870
# 4                           0.121164                             4.121269
# ...                              ...                                  ...
# 79018                       0.191313                            72.820518
# 79019                       0.177222                           -12.856753
# 79020                       0.158418                            -7.925870
# 79021                       0.184209                          -100.344827
# 79022                       0.000000                            76.825638
#
#        SulphurDioxide_sensor_zenith_angle  ...  Cloud_cloud_base_pressure  \
# 0                               50.843559  ...               61085.809570
# 1                               39.137194  ...               66969.478735
# 2                               52.868816  ...               60068.894448
# 3                               37.436189  ...               51064.547339
# 4                               35.515587  ...               63751.125781
# ...                                   ...  ...                        ...
# 79018                           55.988022  ...               60657.101913
# 79019                           19.435339  ...               60168.191528
# 79020                           37.436189  ...               56596.027209
# 79021                           32.599393  ...               46533.348194
# 79022                            8.273742  ...               47771.681887
#
#        Cloud_cloud_base_height  Cloud_cloud_optical_depth  \
# 0                  2615.120483                  15.568533
# 1                  3174.572424                   8.690601
# 2                  3516.282669                  21.103410
# 3                  4180.973322                  15.386899
# 4                  3355.710107                   8.114694
# ...                        ...                        ...
# 79018              4590.879504                  20.245954
# 79019              4659.130378                   6.104610
# 79020              5222.646823                  14.817885
# 79021              6946.858022                  32.594768
# 79022              6553.295018                  19.464032
#
#        Cloud_surface_albedo  Cloud_sensor_azimuth_angle  \
# 0                  0.272292                  -12.628986
# 1                  0.256830                   30.359375
# 2                  0.251101                   15.377883
# 3                  0.262043                  -11.293399
# 4                  0.235847                   38.532263
# ...                     ...                         ...
# 79018              0.304797                  -35.140368
# 79019              0.314015                    4.667058
# 79020              0.288058                   -0.340922
# 79021              0.274047                    8.427699
# 79022              0.226276                  -12.808528
#
#        Cloud_sensor_zenith_angle  Cloud_solar_azimuth_angle  \
# 0                      35.632416                -138.786423
# 1                      39.557633                -145.183930
# 2                      30.401823                -142.519545
# 3                      24.380357                -132.665828
# 4                      37.392979                -141.509805
# ...                          ...                        ...
# 79018                  40.113533                -129.935508
# 79019                  47.528435                -134.252871
# 79020                  35.328098                -134.731723
# 79021                  48.295652                -139.447849
# 79022                  47.923441                -136.299984
#
#        Cloud_solar_zenith_angle   emission      location
# 0                     30.752140   3.750994    29.29-0.51
# 1                     27.251779   4.025176    29.29-0.51
# 2                     26.193296   4.231381    29.29-0.51
# 3                     28.829155   4.305286    29.29-0.51
# 4                     22.204612   4.347317    29.29-0.51
# ...                         ...        ...           ...
# 79018                 32.095214  29.404171  30.301-3.299
# 79019                 30.771469  29.186497  30.301-3.299
# 79020                 30.716166  29.131205  30.301-3.299
# 79021                 29.112868  28.125792  30.301-3.299
# 79022                 30.246387  27.239302  30.301-3.299
#
# [79023 rows x 76 columns]

# %% [markdown]
# 2. Add one aggregation feature representing the average emissions per location (You should groupby "Location" feature and take mean of the "emission", then merge the result to the data)

# %%
# 2. TODO
gp = data.groupby("location").mean("emission")
pd.merge(data,gp,on='location', how="left")
# Out:
#        latitude_x  longitude_x  year_x  week_no_x  \
# 0          -0.510       29.290    2019          0
# 1          -0.510       29.290    2019          1
# 2          -0.510       29.290    2019          2
# 3          -0.510       29.290    2019          3
# 4          -0.510       29.290    2019          4
# ...           ...          ...     ...        ...
# 79018      -3.299       30.301    2021         48
# 79019      -3.299       30.301    2021         49
# 79020      -3.299       30.301    2021         50
# 79021      -3.299       30.301    2021         51
# 79022      -3.299       30.301    2021         52
#
#        SulphurDioxide_SO2_column_number_density_x  \
# 0                                       -0.000108
# 1                                        0.000021
# 2                                        0.000514
# 3                                        0.000048
# 4                                       -0.000079
# ...                                           ...
# 79018                                    0.000284
# 79019                                    0.000083
# 79020                                    0.000048
# 79021                                   -0.000034
# 79022                                   -0.000091
#
#        SulphurDioxide_SO2_column_number_density_amf_x  \
# 0                                            0.603019
# 1                                            0.728214
# 2                                            0.748199
# 3                                            0.834848
# 4                                            0.676296
# ...                                               ...
# 79018                                        1.195643
# 79019                                        1.130868
# 79020                                        0.834848
# 79021                                        0.879397
# 79022                                        0.871951
#
#        SulphurDioxide_SO2_slant_column_number_density_x  \
# 0                                             -0.000065
# 1                                              0.000014
# 2                                              0.000385
# 3                                              0.000035
# 4                                             -0.000048
# ...                                                 ...
# 79018                                          0.000340
# 79019                                          0.000063
# 79020                                          0.000035
# 79021                                         -0.000028
# 79022                                         -0.000079
#
#        SulphurDioxide_cloud_fraction_x  SulphurDioxide_sensor_azimuth_angle_x  \
# 0                             0.255668                             -98.593887
# 1                             0.130988                              16.592861
# 2                             0.110018                              72.795837
# 3                             0.158418                              -7.925870
# 4                             0.121164                               4.121269
# ...                                ...                                    ...
# 79018                         0.191313                              72.820518
# 79019                         0.177222                             -12.856753
# 79020                         0.158418                              -7.925870
# 79021                         0.184209                            -100.344827
# 79022                         0.000000                              76.825638
#
#        SulphurDioxide_sensor_zenith_angle_x  ...  Cloud_cloud_top_height_y  \
# 0                                 50.843559  ...               5514.932587
# 1                                 39.137194  ...               5514.932587
# 2                                 52.868816  ...               5514.932587
# 3                                 37.436189  ...               5514.932587
# 4                                 35.515587  ...               5514.932587
# ...                                     ...  ...                       ...
# 79018                             55.988022  ...               5098.835605
# 79019                             19.435339  ...               5098.835605
# 79020                             37.436189  ...               5098.835605
# 79021                             32.599393  ...               5098.835605
# 79022                              8.273742  ...               5098.835605
#
#        Cloud_cloud_base_pressure_y  Cloud_cloud_base_height_y  \
# 0                     59866.057241                4633.113294
# 1                     59866.057241                4633.113294
# 2                     59866.057241                4633.113294
# 3                     59866.057241                4633.113294
# 4                     59866.057241                4633.113294
# ...                            ...                        ...
# 79018                 63092.148381                4195.419566
# 79019                 63092.148381                4195.419566
# 79020                 63092.148381                4195.419566
# 79021                 63092.148381                4195.419566
# 79022                 63092.148381                4195.419566
#
#        Cloud_cloud_optical_depth_y  Cloud_surface_albedo_y  \
# 0                        15.396998                0.280265
# 1                        15.396998                0.280265
# 2                        15.396998                0.280265
# 3                        15.396998                0.280265
# 4                        15.396998                0.280265
# ...                            ...                     ...
# 79018                    16.865192                0.257280
# 79019                    16.865192                0.257280
# 79020                    16.865192                0.257280
# 79021                    16.865192                0.257280
# 79022                    16.865192                0.257280
#
#        Cloud_sensor_azimuth_angle_y  Cloud_sensor_zenith_angle_y  \
# 0                         -7.924700                    40.631797
# 1                         -7.924700                    40.631797
# 2                         -7.924700                    40.631797
# 3                         -7.924700                    40.631797
# 4                         -7.924700                    40.631797
# ...                             ...                          ...
# 79018                    -13.290426                    41.190859
# 79019                    -13.290426                    41.190859
# 79020                    -13.290426                    41.190859
# 79021                    -13.290426                    41.190859
# 79022                    -13.290426                    41.190859
#
#        Cloud_solar_azimuth_angle_y  Cloud_solar_zenith_angle_y  emission_y
# 0                       -88.566816                   27.784357    4.272966
# 1                       -88.566816                   27.784357    4.272966
# 2                       -88.566816                   27.784357    4.272966
# 3                       -88.566816                   27.784357    4.272966
# 4                       -88.566816                   27.784357    4.272966
# ...                            ...                         ...         ...
# 79018                   -84.873429                   28.170411   27.633301
# 79019                   -84.873429                   28.170411   27.633301
# 79020                   -84.873429                   28.170411   27.633301
# 79021                   -84.873429                   28.170411   27.633301
# 79022                   -84.873429                   28.170411   27.633301
#
# [79023 rows x 151 columns]

# %% [markdown]
# 3. Use Label encoder to encode all the categorical features

# %%
# 3. TODO
from sklearn.preprocessing import LabelEncoder
categ_feats = data.select_dtypes("object").columns
for cat in categ_feats:
  le = LabelEncoder()
  data[cat] = le.fit_transform(data[cat])

# %%
data
# Out:
#        latitude  longitude  year  week_no  \
# 0        -0.510     29.290  2019        0
# 1        -0.510     29.290  2019        1
# 2        -0.510     29.290  2019        2
# 3        -0.510     29.290  2019        3
# 4        -0.510     29.290  2019        4
# ...         ...        ...   ...      ...
# 79018    -3.299     30.301  2021       48
# 79019    -3.299     30.301  2021       49
# 79020    -3.299     30.301  2021       50
# 79021    -3.299     30.301  2021       51
# 79022    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# 2                                      0.000514
# 3                                      0.000048
# 4                                     -0.000079
# ...                                         ...
# 79018                                  0.000284
# 79019                                  0.000083
# 79020                                  0.000048
# 79021                                 -0.000034
# 79022                                 -0.000091
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# 0                                          0.603019
# 1                                          0.728214
# 2                                          0.748199
# 3                                          0.834848
# 4                                          0.676296
# ...                                             ...
# 79018                                      1.195643
# 79019                                      1.130868
# 79020                                      0.834848
# 79021                                      0.879397
# 79022                                      0.871951
#
#        SulphurDioxide_SO2_slant_column_number_density  \
# 0                                           -0.000065
# 1                                            0.000014
# 2                                            0.000385
# 3                                            0.000035
# 4                                           -0.000048
# ...                                               ...
# 79018                                        0.000340
# 79019                                        0.000063
# 79020                                        0.000035
# 79021                                       -0.000028
# 79022                                       -0.000079
#
#        SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# 0                           0.255668                           -98.593887
# 1                           0.130988                            16.592861
# 2                           0.110018                            72.795837
# 3                           0.158418                            -7.925870
# 4                           0.121164                             4.121269
# ...                              ...                                  ...
# 79018                       0.191313                            72.820518
# 79019                       0.177222                           -12.856753
# 79020                       0.158418                            -7.925870
# 79021                       0.184209                          -100.344827
# 79022                       0.000000                            76.825638
#
#        SulphurDioxide_sensor_zenith_angle  ...  Cloud_cloud_base_pressure  \
# 0                               50.843559  ...               61085.809570
# 1                               39.137194  ...               66969.478735
# 2                               52.868816  ...               60068.894448
# 3                               37.436189  ...               51064.547339
# 4                               35.515587  ...               63751.125781
# ...                                   ...  ...                        ...
# 79018                           55.988022  ...               60657.101913
# 79019                           19.435339  ...               60168.191528
# 79020                           37.436189  ...               56596.027209
# 79021                           32.599393  ...               46533.348194
# 79022                            8.273742  ...               47771.681887
#
#        Cloud_cloud_base_height  Cloud_cloud_optical_depth  \
# 0                  2615.120483                  15.568533
# 1                  3174.572424                   8.690601
# 2                  3516.282669                  21.103410
# 3                  4180.973322                  15.386899
# 4                  3355.710107                   8.114694
# ...                        ...                        ...
# 79018              4590.879504                  20.245954
# 79019              4659.130378                   6.104610
# 79020              5222.646823                  14.817885
# 79021              6946.858022                  32.594768
# 79022              6553.295018                  19.464032
#
#        Cloud_surface_albedo  Cloud_sensor_azimuth_angle  \
# 0                  0.272292                  -12.628986
# 1                  0.256830                   30.359375
# 2                  0.251101                   15.377883
# 3                  0.262043                  -11.293399
# 4                  0.235847                   38.532263
# ...                     ...                         ...
# 79018              0.304797                  -35.140368
# 79019              0.314015                    4.667058
# 79020              0.288058                   -0.340922
# 79021              0.274047                    8.427699
# 79022              0.226276                  -12.808528
#
#        Cloud_sensor_zenith_angle  Cloud_solar_azimuth_angle  \
# 0                      35.632416                -138.786423
# 1                      39.557633                -145.183930
# 2                      30.401823                -142.519545
# 3                      24.380357                -132.665828
# 4                      37.392979                -141.509805
# ...                          ...                        ...
# 79018                  40.113533                -129.935508
# 79019                  47.528435                -134.252871
# 79020                  35.328098                -134.731723
# 79021                  48.295652                -139.447849
# 79022                  47.923441                -136.299984
#
#        Cloud_solar_zenith_angle   emission  location
# 0                     30.752140   3.750994       129
# 1                     27.251779   4.025176       129
# 2                     26.193296   4.231381       129
# 3                     28.829155   4.305286       129
# 4                     22.204612   4.347317       129
# ...                         ...        ...       ...
# 79018                 32.095214  29.404171       330
# 79019                 30.771469  29.186497       330
# 79020                 30.716166  29.131205       330
# 79021                 29.112868  28.125792       330
# 79022                 30.246387  27.239302       330
#
# [79023 rows x 76 columns]

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Baseline:

# %%
X = data.drop('emission',axis=1)
y = data['emission']

# %% [markdown]
# 1. Create a baseline using the "emission" median and calculate MAE score.

# %%
# 1. TODO
import numpy as np
from sklearn.metrics import mean_absolute_error
baseline = np.full_like(y,y.median())
mean_absolute_error(baseline,y)
# Out:
# 67.10104302548434

# %% [markdown]
# 2. Perform a Time-Based Train-Test Split:
#   * You will use the "year" column to split data manually using pandas.
#   * Use all samples from 2019 and 2020 as the training set.
#   * Use all samples from 2021 as the validation set.
#   * Construct X_train, X_valid, y_train, y_valid

# %%
X.year.value_counts()
# Out:
# year
# 2019    26341
# 2020    26341
# 2021    26341
# Name: count, dtype: int64

# %%
# 2. TODO
X_train = X[X["year"] < 2021]
X_valid = X[X["year"] == 2021]
y_train = y[X_train.index]
y_valid = y[X_valid.index]

# %% [markdown]
# 3. Train a LGBMRegressor on the training data.

# %%
# 3. TODO
from lightgbm import LGBMRegressor
model = LGBMRegressor(max_depth=6)
model.fit(X_train,y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.163520 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16886
# [LightGBM] [Info] Number of data points in the train set: 52682, number of used features: 68
# [LightGBM] [Info] Start training from score 81.623719
# LGBMRegressor(max_depth=6)

# %% [markdown]
# 4. Evaluate the Model on the validation data Using MAE

# %%
# 4. TODO
y_pred = model.predict(X_valid)
mean_absolute_error(y_pred,y_valid)
# Out:
# 26.555736846724294

# %% [markdown]
# 5. Plot the features importance of your model.

# %%
# 5. TODO
# Feature importance
feature_importance = pd.DataFrame({
    'feature': X.columns,
    'importance': model.feature_importances_
}).sort_values('importance', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_importance['feature'], feature_importance['importance'])
plt.xlabel('Importance')
plt.title('Feature Importance')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# 6. Plot the validation predictions using a histogram.

# %%
# 6. TODO
pd.Series(y_pred).hist()
# Out:
# <Axes: >
